# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/fraud-detection-ml-project/blob/main/notebooks/02_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/creditcard.csv")

# %%
sns.countplot(x="Class", data=df)
plt.title("Fraud vs Normal Transactions")
plt.show()

# %%
sns.histplot(df["Amount"], bins=50)
plt.title("Transaction Amount Distribution")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
